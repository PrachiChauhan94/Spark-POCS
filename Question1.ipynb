# %%
import os
import pandas as pd
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords
from stemming.porter2 import stem
import random

from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer


path_pos="C:\\Users\\Algorathmic\\Downloads\\Python Programming\\Python Programming\\movie_reviews\\pos"
path_neg="C:\\Users\\Algorathmic\\Downloads\\Python Programming\\Python Programming\\movie_reviews\\neg"

def preprocess( raw_review ):
    review_text = BeautifulSoup(raw_review).get_text()        
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    words = letters_only.lower().replace("\'","").encode('Utf-8').split()
    
    # Stop Word Removal
    stops = set(stopwords.words("english"))                  
    meaningful_words = [stem(w) for w in words]   
    
    # Stemming
    for i in range(1,len(meaningful_words)):
            meaningful_words[i]=stem(meaningful_words[i])
            
    return( " ".join( meaningful_words))  

def create_dataframe(path,name):
    df = pd.DataFrame(columns=['File','Text','Review'])
    for root, dirs, files in os.walk(path):
        for fname in files:
            src = os.path.join(root, fname)
            text=open(src, "r")
            x = preprocess(text.read())
            y = name
            df=df.append(pd.Series([fname,x,y], index=['File','Text','Review']), ignore_index=True)
    return df

# %%
df1 = create_dataframe(path_pos,'pos')
df2 = create_dataframe(path_neg,'neg')
Frame = df1.append(pd.DataFrame(data=df2),ignore_index=True)
Frame['Review'] = Frame['Review'].map({'pos': 1, 'neg': 0})

# %%
n1 = len(df1)
n2 = len(df2)
total = n1+n2
split_n = (30*total)/100
rows = random.sample(Frame.index, split_n)
test = Frame.ix[rows]
train = Frame.drop(rows)

# %%
train.groupby('Review').count()  # 50 : 50
# Out:
#         File  Text
# Review
# neg      709   709
# pos      691   691

# %%
test.groupby('Review').count() # 49 : 51
# Out:
#         File  Text
# Review
# neg      291   291
# pos      309   309

# %%
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000) 

train_data_features = vectorizer.fit_transform(train['Text']).toarray()
test_data_features = vectorizer.fit_transform(test['Text']).toarray()

# %%
##### Get The List of Features
vocab = vectorizer.get_feature_names()
print vocab
# Out:
# [u'abandon', u'abil', u'abl', u'aboard', u'abort', u'abound', u'abrupt', u'absenc', u'absent', u'absolut', u'absorb', u'absurd', u'abus', u'abyss', u'academi', u'accent', u'accept', u'access', u'accid', u'accident', u'acclaim', u'accompani', u'accomplish', u'accord', u'account', u'accur', u'accuraci', u'accus', u'ace', u'achiev', u'acid', u'acknowledg', u'across', u'act', u'action', u'activ', u'actor', u'actress', u'actual', u'ad', u'adam', u'adapt', u'add', u'addict', u'addit', u'address', u'adequ', u'admir', u'admit', u'adolesc', u'adopt', u'ador', u'adrenalin', u'adult', u'advanc', u'advantag', u'adventur', u'advertis', u'advic', u'advis', u'advoc', u'affair', u'affect', u'affleck', u'afford', u'aforement', u'afraid', u'africa', u'african', u'afternoon', u'afterward', u'age', u'agenda', u'agent', u'aggress', u'ago', u'agre', u'ahead', u'ahm', u'aid', u'aim', u'ain', u'air', u'airplan', u'airport', u'al', u'ala', u'alain', u'alan', u'albeit', u'albert', u'alcohol', u'alec', u'alex', u'alexand', u'alfr', u'ali', u'alic', u'alicia', u'alien', u'alik', u'aliv', u'alleg', u'allen', u'alley', u'alli', u'allison', u'allow', u'allur', u'almost', u'alon', u'along', u'alongsid', u'alreadi', u'also', u'alter', u'altern', u'although', u'altman', u'altogeth', u'alway', u'amanda', u'amaz', u'ambigu', u'ambit', u'ambiti', u'america', u'american', u'ami', u'amidst', u'amistad', u'among', u'amongst', u'amor', u'amount', u'amus', u'anaconda', u'anakin', u'analysi', u'analyz', u'anastasia', u'ancient', u'anderson', u'andi', u'andrew', u'angel', u'angela', u'angelina', u'anger', u'angl', u'angri', u'angst', u'anim', u'ann', u'anna', u'annett', u'anni', u'announc', u'annoy', u'anonym', u'anoth', u'answer', u'ant', u'antagonist', u'anthoni', u'anti', u'antic', u'anticip', u'antonio', u'antz', u'anybodi', u'anymor', u'anyon', u'anyth', u'anyway', u'anywher', u'apart', u'ape', u'apocalyps', u'apollo', u'apolog', u'apostl', u'appal', u'appar', u'appeal', u'appear', u'appl', u'appli', u'appreci', u'approach', u'appropri', u'approxim', u'april', u'apt', u'arab', u'arc', u'archer', u'area', u'aren', u'argento', u'argu', u'arguabl', u'argument', u'aris', u'arizona', u'ark', u'arkin', u'arm', u'armageddon', u'armi', u'armor', u'arnold', u'around', u'arquett', u'arrang', u'array', u'arrest', u'arriv', u'arrog', u'arrow', u'art', u'arthur', u'artifici', u'artist', u'ash', u'ashley', u'asian', u'asid', u'ask', u'asleep', u'aspect', u'aspir', u'ass', u'assassin', u'assault', u'assembl', u'asset', u'assign', u'assist', u'associ', u'assort', u'assum', u'assur', u'asteroid', u'astonish', u'astound', u'astronaut', u'atheist', u'atlant', u'atmospher', u'atom', u'atroc', u'atroci', u'attach', u'attack', u'attain', u'attempt', u'attend', u'attent', u'attitud', u'attorney', u'attract', u'attribut', u'audienc', u'audio', u'audrey', u'august', u'austin', u'australia', u'australian', u'auteur', u'authent', u'author', u'auto', u'automat', u'automobil', u'avail', u'aveng', u'averag', u'avoid', u'aw', u'await', u'awak', u'awaken', u'awar', u'award', u'away', u'awe', u'awesom', u'awhil', u'awkward', u'awri', u'azaria', u'ba', u'babe', u'babi', u'babysitt', u'bachelor', u'back', u'backdrop', u'background', u'bacon', u'bad', u'baffl', u'bag', u'bail', u'bake', u'baker', u'balanc', u'baldwin', u'ball', u'banal', u'banana', u'band', u'bandera', u'bandit', u'bang', u'bank', u'banter', u'bar', u'barbara', u'bare', u'bargain', u'barn', u'barrel', u'barri', u'barrymor', u'bartend', u'base', u'basebal', u'basement', u'bash', u'basi', u'basic', u'basketbal', u'bastard', u'bat', u'bate', u'bath', u'bathroom', u'bathtub', u'batman', u'battl', u'battlefield', u'bay', u'be', u'beach', u'beam', u'bean', u'bear', u'beast', u'beat', u'beaten', u'beatric', u'beatti', u'beauti', u'beavi', u'becam', u'beck', u'becom', u'bed', u'bedroom', u'beek', u'beer', u'befriend', u'beg', u'began', u'begin', u'begun', u'behav', u'behavior', u'behind', u'behold', u'belief', u'believ', u'bell', u'belli', u ...

# %%
#### Count the Frequecy of Each Feature
dist = np.sum(train_data_features, axis=0)
for tag, count in zip(vocab, dist):
    print count, tag
# Out:
# 70 abandon
# 120 abil
# 226 abl
# 26 aboard
# 15 abort
# 13 abound
# 17 abrupt
# 18 absenc
# 22 absent
# 159 absolut
# 37 absorb
# 54 absurd
# 55 abus
# 17 abyss
# 69 academi
# 89 accent
# 123 accept
# 22 access
# 75 accid
# 48 accident
# 30 acclaim
# 43 accompani
# 84 accomplish
# 42 accord
# 43 account
# 34 accur
# 16 accuraci
# 47 accus
# 21 ace
# 117 achiev
# 17 acid
# 19 acknowledg
# 152 across
# 788 act
# 911 action
# 51 activ
# 871 actor
# 174 actress
# 712 actual
# 148 ad
# 111 adam
# 117 adapt
# 203 add
# 43 addict
# 95 addit
# 26 address
# 34 adequ
# 93 admir
# 133 admit
# 15 adolesc
# 37 adopt
# 31 ador
# 13 adrenalin
# 127 adult
# 58 advanc
# 30 advantag
# 130 adventur
# 34 advertis
# 33 advic
# 24 advis
# 29 advoc
# 76 affair
# 79 affect
# 68 affleck
# 13 afford
# 37 aforement
# 49 afraid
# 31 africa
# 58 african
# 13 afternoon
# 35 afterward
# 208 age
# 13 agenda
# 159 agent
# 19 aggress
# 132 ago
# 95 agre
# 43 ahead
# 13 ahm
# 71 aid
# 51 aim
# 25 ain
# 130 air
# 32 airplan
# 22 airport
# 60 al
# 43 ala
# 14 alain
# 77 alan
# 36 albeit
# 34 albert
# 37 alcohol
# 29 alec
# 52 alex
# 19 alexand
# 28 alfr
# 32 ali
# 46 alic
# 41 alicia
# 499 alien
# 14 alik
# 87 aliv
# 15 alleg
# 96 allen
# 13 alley
# 21 alli
# 13 allison
# 180 allow
# 16 allur
# 601 almost
# 173 alon
# 369 along
# 13 alongsid
# 192 alreadi
# 1424 also
# 35 alter
# 55 altern
# 551 although
# 41 altman
# 29 altogeth
# 404 alway
# 29 amanda
# 169 amaz
# 23 ambigu
# 28 ambit
# 35 ambiti
# 169 america
# 429 american
# 68 ami
# 16 amidst
# 33 amistad
# 162 among
# 21 amongst
# 15 amor
# 120 amount
# 141 amus
# 38 anaconda
# 25 anakin
# 13 analysi
# 23 analyz
# 19 anastasia
# 27 ancient
# 73 anderson
# 48 andi
# 40 andrew
# 177 angel
# 21 angela
# 14 angelina
# 37 anger
# 68 angl
# 56 angri
# 16 angst
# 365 anim
# 78 ann
# 49 anna
# 15 annett
# 53 anni
# 38 announc
# 183 annoy
# 14 anonym
# 802 anoth
# 132 answer
# 32 ant
# 14 antagonist
# 46 anthoni
# 69 anti
# 32 antic
# 39 anticip
# 26 antonio
# 35 antz
# 33 anybodi
# 32 anymor
# 284 anyon
# 453 anyth
# 138 anyway
# 34 anywher
# 163 apart
# 116 ape
# 16 apocalyps
# 13 apollo
# 19 apolog
# 25 apostl
# 18 appal
# 219 appar
# 136 appeal
# 485 appear
# 20 appl
# 23 appli
# 93 appreci
# 133 approach
# 80 appropri
# 15 approxim
# 16 april
# 30 apt
# 13 arab
# 19 arc
# 14 archer
# 52 area
# 186 aren
# 27 argento
# 52 argu
# 22 arguabl
# 24 argument
# 19 aris
# 21 arizona
# 18 ark
# 17 arkin
# 110 arm
# 47 armageddon
# 95 armi
# 16 armor
# 75 arnold
# 643 around
# 51 arquett
# 21 arrang
# 17 array
# 39 arrest
# 126 arriv
# 30 arrog
# 15 arrow
# 175 art
# 32 arthur
# 30 artifici
# 115 artist
# 21 ash
# 28 ashley
# 25 asian
# 85 asid
# 301 ask
# 25 asleep
# 167 aspect
# 32 aspir
# 88 ass
# 52 assassin
# 33 assault
# 32 assembl
# 16 asset
# 52 assign
# 76 assist
# 55 associ
# 18 assort
# 67 assum
# 43 assur
# 18 asteroid
# 34 astonish
# 20 astound
# 63 astronaut
# 13 atheist
# 13 atlant
# 107 atmospher
# 17 atom
# 13 atroc
# 15 atroci
# 30 attach
# 137 attack
# 12 attain
# 417 attempt
# 49 attend
# 187 attent
# 72 attitud
# 25 attorney
# 127 attract
# 23 attribut
# 758 audienc
# 19 audio
# 13 audrey
# 30 august
# 33 austin
# 12 australia
# 19 australian
# 15 auteur
# 35 authent
# 102 author
# 14 auto
# 24 automat
# 18 automobil
# 60 avail
# 23 aveng
# 79 averag
# 104 avoid
# 125 aw
# 34 await
# 24 awak
# 24 awaken
# 52 awar
# 103 award
# 460 away
# 20 awe
# 30 awesom
# 14 awhil
# 37 awkward
# 23 awri
# 20 azaria
# 12 ba
# 73 babe
# 111 babi
# 18 babysitt
# 24 bachelor
# 758 back
# 26 backdrop
# 107 background
# 35 bacon
# 1054 bad
# 14 baffl
# 48 bag
# 16 bail
# 12 bake
# 41 baker
# 44 balanc
# 61 baldwin
# 62 ball
# 18 banal
# 16 banana
# 73 band
# 32 bandera
# 16 bandit
# 50 bang
# 65 bank
# 14 banter
# 72 bar
# 22 barbara
# 109 bare
# 17 bargain
# 23 barn
# 22 barrel
# 47 barri
# 45 barrymor
# 13 bartend
# 312 base
# 53 basebal
# 16 basement
# 13 bash
# 37 basi
# 246 basic
# 35 basketbal
# 33 bastard
# 40 bat
# 23 bate
# 16 bath
# 35 bathroom
# 13 bathtub
# 151 batman
# 201 battl
# 33 battlefield
# 27 bay
# 25 be
# 57 beach
# 16 beam
# 22 bean
# 68 bear
# 51 beast
# 104 beat
# 20 beaten
# 15 beatric
# 41 beatti
# 328 beauti
# 15 beavi
# 73 becam
# 16 beck
# 805 becom
# 55 bed
# 14 bedroom
# 13 beek
# 19 beer
# 31 befriend
# 21 beg
# 51 began
# 610 begin
# 13 begun
# 17 behav
# 45 behavior
# 257 behind
# 22 behold
# 41 belief
# 477 believ
# 27 bell
# 15 belli
# 55 belong
# 57 belov
# 13 belt
# 130 ben
# 18 bene
# 20 beneath
# 39 benefit
# 14 benigni
# 15 bent
# 16 bergman
# 17 bernard
# 56 besid
# 33 besson
# 944 best
# 49 bet
# 34 betray
# 641 better
# 34 betti
# 27 bever
# 134 beyond
# 19 bibl
# 23 bicker
# 785 big
# 16 bigg
# 42 bigger
# 95 biggest
# 15 bilko
# 154 bill
# 86 billi
# 17 billion
# 16 birch
# 33 bird
# 41 birth
# 30 birthday
# 418 bit
# 19 bitch
# 34 bite
# 52 bitter
# 94 bizarr
# 365 black
# 12 blackmail
# 75 blade
# 21 blah
# 57 blair
# 25 blake
# 66 blame
# 66 bland
# 39 blank
# 32 blast
# 40 blatant
# 13 blaze
# 39 bleak
# 16 bleed
# 26 blend
# 20 bless
# 39 blind
# 14 bliss
# 42 block
# 56 blockbust
# 56 blond
# 150 blood
# 46 bloodi
# 18 blossom
# 78 blow
# 38 blown
# 128 blue
# 14 blunt
# 76 board
# 38 boast
# 78 boat
# 109 bob
# 35 bobbi
# 224 bodi
# 13 bog
# 37 boil
# 15 boiler
# 20 bold
# 70 bomb
# 12 bomber
# 97 bond
# 57 bone
# 26 bont
# 40 boogi
# 280 book
# 14 booker
# 14 booksel
# 18 bookstor
# 14 boom
# 16 boorman
# 14 boost
# 24 boot
# 14 booz
# 37 border
# 297 bore
# 17 boredom
# 68 born
# 50 borrow
# 89 boss
# 18 boston
# 14 botch
# 53 bother
# 22 bottl
# 64 bottom
# 24 bought
# 19 bounc
# 41 bound
# 13 boundari
# 14 bow
# 13 bowel
# 26 bowfing
# 42 bowl
# 13 bowler
# 162 box
# 13 boxer
# 308 boy
# 69 boyfriend
# 23 boyl
# 41 brad
# 17 bradi
# 96 brain
# 42 branagh
# 30 brand
# 24 brandi
# 21 brave
# 37 braveheart
# 13 brazil
# 14 bread
# 226 break
# 30 breakdown
# 13 breakfast
# 41 breast
# 54 breath
# 29 breathtak
# 23 breed
# 30 brenner
# 49 brian
# 33 bride
# 71 bridg
# 18 bridget
# 99 brief
# 23 briefli
# 13 brigg
# 82 bright
# 18 brillianc
# 164 brilliant
# 389 bring
# 13 brink
# 110 british
# 33 broad
# 39 broadcast
# 17 broadway
# 29 broderick
# 19 broke
# 58 broken
# 15 bronson
# 12 bronx
# 18 brood
# 74 brook
# 14 brooklyn
# 18 bros
# 19 brosnan
# 313 brother
# 118 brought
# 89 brown
# 121 bruce
# 18 bruckheim
# 12 bruno
# 12 brush
# 61 brutal
# 18 bubbi
# 28 bubbl
# 51 buck
# 20 bud
# 86 buddi
# 141 budget
# 21 buff
# 106 bug
# 190 build
# 50 built
# 17 bulk
# 39 bullet
# 30 bulli
# 22 bullock
# 44 bulworth
# 14 bum
# 23 bumbl
# 26 bump
# 128 bunch
# 26 bunni
# 14 burbank
# 14 burden
# 31 buri
# 74 burn
# 33 burst
# 66 burton
# 54 bus
# 25 buscemi
# 13 bush
# 165 busi
# 16 businessman
# 22 bust
# 25 butcher
# 19 butler
# 33 butt
# 14 button
# 92 buy
# 43 buzz
# 21 bye
# 19 byrn
# 24 caan
# 25 cab
# 14 cabin
# 40 cabl
# 94 cage
# 22 cain
# 18 cake
# 15 cal
# 13 calcul
# 19 calib
# 28 california
# 500 call
# 27 calm
# 125 came
# 99 cameo
# 262 camera
# 13 camerawork
# 115 cameron
# 91 camp
# 31 campaign
# 61 campbel
# 28 campi
# 16 campus
# 22 canadian
# 14 cancer
# 32 candi
# 24 candid
# 21 cannib
# 105 cannot
# 15 cap
# 48 capabl
# 14 capac
# 17 cape
# 29 capit
# 17 capon
# 27 capsule
# 65 captain
# 41 captiv
# 119 captur
# 295 car
# 48 card
# 26 cardboard
# 354 care
# 188 career
# 31 caricatur
# 32 carl
# 13 carla
# 13 carlyl
# 14 carmen
# 16 carnag
# 32 carol
# 58 carpent
# 75 carrey
# 195 carri
# 108 carter
# 59 cartoon
# 18 cartoonish
# 26 casablanca
# 324 case
# 75 cash
# 23 casino
# 16 casper
# 627 cast
# 30 castl
# 15 casual
# 43 cat
# 12 catastroph
# 109 catch
# 21 catchi
# 35 categori
# 48 catherin
# 29 cathol
# 87 caught
# 14 caulder
# 40 cauldron
# 155 caus
# 33 cave
# 12 caveman
# 82 celebr
# 54 cell
# 12 celluloid
# 83 center
# 82 central
# 92 centuri
# 13 ceremoni
# 368 certain
# 43 cgi
# 27 chad
# 43 chain
# 16 chainsaw
# 34 chair
# 93 challeng
# 26 chamber
# 25 champion
# 118 chan
# 189 chanc
# 321 chang
# 26 channel
# 27 chao
# 17 chapter
# 2703 charact
# 79 character
# 17 characterist
# 79 charg
# 32 charisma
# 25 charismat
# 64 charl
# 42 charli
# 14 charliz
# 16 charlott
# 196 charm
# 206 chase
# 13 chat
# 15 cheadl
# 103 cheap
# 50 cheat
# 75 check
# 24 cheek
# 50 cheer
# 16 cheerlead
# 18 chees
# 49 cheesi
# 93 chemistri
# 15 chest
# 24 chew
# 42 chicago
# 23 chick
# 37 chicken
# 43 chief
# 185 child
# 36 childhood
# 13 childish
# 245 children
# 46 chill
# 38 china
# 80 chines
# 18 chocol
# 16 chocolat
# 134 choic
# 57 choos
# 23 chop
# 28 choreograph
# 30 chose
# 67 chosen
# 18 chow
# 154 chris
# 32 christ
# 46 christian
# 24 christin
# 25 christina
# 60 christma
# 76 christoph
# 27 chronicl
# 15 chuck
# 20 chucki
# 45 chuckl
# 15 chunk
# 57 church
# 15 churn
# 21 cia
# 22 cigarett
# 17 cindi
# 132 cinema
# 98 cinemat
# 49 cinematograph
# 92 cinematographi
# 19 cinqu
# 31 circl
# 46 circumst
# 13 circus
# 356 citi
# 39 citizen
# 58 civil
# 19 clad
# 85 claim
# 41 clair
# 18 clan
# 28 clark
# 21 clash
# 133 class
# 247 classic
# 27 claud
# 19 claw
# 63 clean
# 218 clear
# 32 clerk
# 149 clever
# 201 clich
# 14 click
# 29 client
# 19 cliff
# 14 cliffhang
# 44 climact
# 89 climax
# 24 climb
# 21 clinic
# 24 clint
# 20 clip
# 16 clock
# 27 clone
# 48 clooney
# 277 close
# 36 closer
# 15 closest
# 61 cloth
# 31 cloud
# 27 clown
# 87 club
# 54 clue
# 46 clueless
# 17 clumsi
# 14 clutch
# 167 co
# 42 coach
# 19 coast
# 33 coat
# 15 cocain
# 15 cocki
# 29 code
# 53 coen
# 19 coffe
# 26 coher
# 37 coincid
# 25 col
# 123 cold
# 36 cole
# 31 collabor
# 17 collaps
# 19 colleagu
# 86 collect
# 13 collector
# 94 colleg
# 36 colonel
# 22 coloni
# 150 color
# 24 colour
# 14 columbia
# 28 com
# 13 coma
# 29 combat
# 91 combin
# 1291 come
# 17 comeback
# 60 comed
# 658 comedi
# 16 comedian
# 38 comet
# 57 comfort
# 293 comic
# 101 command
# 16 commend
# 58 comment
# 46 commentari
# 77 commerci
# 80 commit
# 107 common
# 45 communic
# 45 communiti
# 140 compani
# 23 companion
# 112 compar
# 71 comparison
# 18 compass
# 56 compel
# 22 compens
# 31 compet
# 31 competit
# 42 complain
# 24 complaint
# 479 complet
# 121 complex
# 53 complic
# 15 compliment
# 51 compos
# 16 compris
# 13 compromis
# 200 comput
# 56 con
# 27 conceiv
# 40 concentr
# 101 concept
# 111 concern
# 18 concert
# 25 conclud
# 91 conclus
# 18 concoct
# 17 condemn
# 30 condit
# 14 condor
# 15 conduct
# 26 confess
# 48 confid
# 21 confin
# 21 confirm
# 84 conflict
# 88 confront
# 169 confus
# 13 congreg
# 14 conjur
# 104 connect
# 31 conneri
# 35 connor
# 13 conquer
# 16 conrad
# 24 conscienc
# 32 conscious
# 50 consequ
# 16 conserv
# 247 consid
# 55 consider
# 98 consist
# 14 conspir
# 49 conspiraci
# 147 constant
# 42 construct
# 24 consum
# 82 contact
# 150 contain
# 38 contemporari
# 13 contempt
# 15 contend
# 65 content
# 26 contest
# 28 context
# 174 continu
# 20 contract
# 13 contradict
# 16 contrari
# 56 contrast
# 48 contribut
# 73 contriv
# 146 control
# 33 controversi
# 49 conveni
# 72 convent
# 66 convers
# 50 convey
# 64 convict
# 197 convinc
# 20 convolut
# 38 cook
# 27 cooki
# 155 cool
# 28 cooper
# 211 cop
# 23 cope
# 59 copi
# 22 coppola
# 13 copyright
# 42 core
# 52 corner
# 36 corni
# 30 corpor
# 28 corps
# 49 correct
# 48 corrupt
# 51 cost
# 43 costner
# 101 costum
# 14 cotton
# 14 couch
# 1037 could
# 123 couldn
# 14 counselor
# 104 count
# 22 counterpart
# 37 countless
# 138 countri
# 332 coupl
# 26 courag
# 465 cours
# 62 court
# 17 courtesi
# 36 courtney
# 45 courtroom
# 36 cousin
# 148 cover
# 47 cowboy
# 31 cox
# 13 crab
# 65 crack
# 56 craft
# 19 craig
# 72 crap
# 88 crash
# 28 craven
# 25 crawford
# 20 crawl
# 31 craze
# 65 crazi
# 12 creaki
# 16 cream
# 384 creat
# 39 creation
# 77 creativ
# 39 creator
# 91 creatur
# 52 credibl
# 254 credit
# 20 creek
# 18 creep
# 76 creepi
# 165 crew
# 64 cri
# 17 crichton
# 171 crime
# 84 crimin
# 23 cring
# 44 crisi
# 21 crisp
# 228 critic
# 48 critiqu
# 13 croft
# 22 cromwel
# 16 cronenberg
# 26 crook
# 120 cross
# 54 crow
# 72 crowd
# 32 crucial
# 27 crude
# 30 cruel
# 14 cruelti
# 61 cruis
# 17 crusad
# 32 crush
# 50 crystal
# 29 cuba
# 16 cuban
# 15 cube
# 18 cue
# 17 culmin
# 61 cult
# 94 cultur
# 16 cum
# 15 cup
# 23 cure
# 19 curios
# 38 curious
# 77 current
# 22 curs
# 27 curti
# 65 cusack
# 13 custodi
# 41 custom
# 238 cut
# 92 cute
# 52 cynic
# 17 cynthia
# 65 dad
# 24 daddi
# 18 dafo
# 14 daili
# 21 daisi
# 17 dalmatian
# 34 damag
# 67 damm
# 87 damn
# 50 damon
# 34 dan
# 114 danc
# 20 dancer
# 22 dane
# 115 danger
# 57 daniel
# 83 danni
# 19 dant
# 53 dare
# 277 dark
# 18 darker
# 13 darn
# 22 darth
# 17 daryl
# 17 dash
# 17 data
# 137 date
# 257 daughter
# 22 dave
# 30 davi
# 261 david
# 18 davidson
# 23 dawn
# 27 dawson
# 735 day
# 18 daylight
# 33 dazzl
# 158 de
# 349 dead
# 282 deal
# 39 dealer
# 22 dealt
# 43 dean
# 18 dear
# 332 death
# 31 debat
# 19 debt
# 76 debut
# 96 decad
# 16 decapit
# 16 decemb
# 124 decent
# 17 decept
# 327 decid
# 85 decis
# 24 deck
# 31 declar
# 16 declin
# 22 decor
# 33 dedic
# 13 deed
# 19 deedl
# 17 deem
# 200 deep
# 40 deeper
# 39 deepli
# 25 defeat
# 36 defend
# 40 defens
# 23 defi
# 63 defin
# 170 definit
# 13 deft
# 31 degener
# 48 degre
# 19 del
# 24 deliber
# 14 delic
# 25 delici
# 98 delight
# 209 deliv
# 29 deliveri
# 20 delv
# 69 demand
# 17 demeanor
# 16 dement
# 17 demis
# 38 demon
# 63 demonstr
# 50 deni
# 31 deniro
# 21 denis
# 67 denni
# 15 denver
# 16 denzel
# 57 depart
# 14 departur
# 41 depend
# 72 depict
# 28 depp
# 91 depress
# 122 depth
# 16 der
# 49 derek
# 30 deriv
# 18 descend
# 121 describ
# 27 descript
# 62 desert
# 164 deserv
# 150 design
# 71 desir
# 18 despair
# 127 desper
# 243 despit
# 50 destin
# 20 destini
# 129 destroy
# 50 destruct
# 20 detach
# 182 detail
# 111 detect
# 88 determin
# 17 detract
# 25 deuc
# 29 devast
# 284 develop
# 89 devic
# 78 devil
# 16 devin
# 13 devis
# 27 devito
# 18 devoid
# 40 devot
# 13 dewey
# 17 di
# 13 diabol
# 35 dialog
# 371 dialogu
# 35 diamond
# 19 dian
# 20 diari
# 26 diaz
# 38 dicaprio
# 13 dice
# 45 dick
# 412 didn
# 323 die
# 20 dien
# 404 differ
# 140 difficult
# 15 difficulti
# 29 dig
# 15 digest
# 51 digit
# 27 digniti
# 21 dilemma
# 28 dillon
# 26 dim
# 19 dimens
# 69 dimension
# 19 diner
# 50 dinner
# 13 dino
# 36 dinosaur
# 661 direct
# 962 director
# 33 directori
# 14 dirt
# 38 dirti
# 69 disappear
# 168 disappoint
# 99 disast
# 15 disastr
# 38 disbelief
# 40 disc
# 13 discern
# 26 disco
# 220 discov
# 34 discoveri
# 68 discuss
# 20 diseas
# 41 disguis
# 38 disgust
# 12 disjoint
# 23 dislik
# 21 dismal
# 17 dismay
# 17 dismiss
# 169 disney
# 13 dispatch
# 97 display
# 25 dispos
# 12 dissolv
# 39 distanc
# 21 distant
# 44 distinct
# 20 distinguish
# 87 distract
# 15 distress
# 14 distribut
# 13 distributor
# 104 disturb
# 12 ditch
# 16 dive
# 25 divers
# 12 divert
# 21 divid
# 39 divorc
# 23 dizzi
# 15 dna
# 115 doctor
# 19 document
# 67 documentari
# 855 doesn
# 202 dog
# 24 dogma
# 31 doll
# 92 dollar
# 18 domest
# 37 domin
# 32 donald
# 368 done
# 45 donnel
# 30 donni
# 17 doo
# 52 doom
# 120 door
# 20 dora
# 13 dorn
# 20 dose
# 103 doubl
# 152 doubt
# 16 doug
# 83 dougla
# 13 dove
# 16 down
# 18 downey
# 18 downhil
# 32 downright
# 68 dozen
# 160 dr
# 15 dracula
# 14 draft
# 78 drag
# 38 dragon
# 13 drain
# 247 drama
# 171 dramat
# 12 drastic
# 91 draw
# 58 drawn
# 56 dread
# 218 dream
# 25 dreamwork
# 21 dreari
# 104 dress
# 39 drew
# 25 dreyfuss
# 33 dri
# 21 drift
# 59 drink
# 166 drive
# 13 drivel
# 47 driven
# 70 driver
# 112 drop
# 34 drown
# 203 drug
# 37 drunk
# 34 drunken
# 32 dub
# 20 dubious
# 33 duchovni
# 22 duck
# 17 dud
# 93 dude
# 140 due
# 27 duke
# 107 dull
# 123 dumb
# 18 dumber
# 33 dump
# 13 duncan
# 22 dune
# 14 dunn
# 25 duo
# 14 dusk
# 18 dust
# 14 dustin
# 19 dutch
# 32 duti
# 61 duval
# 71 dvd
# 13 dwayn
# 20 dylan
# 23 dynam
# 17 dysfunct
# 45 eager
# 31 ear
# 13 earl
# 202 earli
# 90 earlier
# 55 earn
# 22 earnest
# 13 earp
# 249 earth
# 22 eas
# 153 easi
# 29 easier
# 164 easili
# 19 east
# 34 eastwood
# 106 eat
# 24 ebert
# 54 eccentr
# 26 echo
# 13 econom
# 59 ed
# 101 eddi
# 90 edg
# 15 edgi
# 135 edit
# 34 editor
# 25 educ
# 65 edward
# 31 eeri
# 776 effect
# 23 effici
# 137 effort
# 22 effortless
# 25 egg
# 20 ego
# 24 egoyan
# 13 egypt
# 13 eh
# 57 eight
# 18 eighti
# 265 either
# 42 elabor
# 30 elder
# 30 elect
# 18 electr
# 15 electron
# 18 eleg
# 259 element
# 24 elev
# 19 elfman
# 13 elicit
# 25 elimin
# 14 elisabeth
# 22 elit
# 60 elizabeth
# 31 ellen
# 58 elli
# 21 elliot
# 280 els
# 16 elsewher
# 14 elvi
# 22 em
# 94 embarrass
# 17 embodi
# 27 embrac
# 43 emerg
# 30 emili
# 38 emma
# 24 emmerich
# 355 emot
# 26 emperor
# 18 emphas
# 16 emphasi
# 26 empir
# 56 employ
# 30 employe
# 52 empti
# 24 en
# 18 enchant
# 96 encount
# 22 encourag
# 1327 end
# 13 endang
# 38 endear
# 56 endless
# 50 endur
# 51 enemi
# 34 energet
# 78 energi
# 13 enforc
# 130 engag
# 39 engin
# 42 england
# 118 english
# 22 engross
# 40 enhanc
# 438 enjoy
# 18 enlist
# 38 enorm
# 661 enough
# 43 ensembl
# 48 ensu
# 16 ensur
# 94 enter
# 26 enterpris
# 433 entertain
# 27 enthusiast
# 372 entir
# 18 entitl
# 15 entranc
# 37 entri
# 36 environ
# 17 envis
# 19 ephron
# 79 epic
# 109 episod
# 16 epp
# 140 equal
# 15 equat
# 25 equip
# 17 equival
# 18 er
# 58 era
# 16 eras
# 44 eric
# 37 erot
# 13 error
# 175 escap
# 318 especi
# 34 esqu
# 20 essenc
# 68 essenti
# 74 establish
# 15 estat
# 17 estella
# 18 estrang
# 21 eszterha
# 97 etc
# 27 etern
# 43 ethan
# 18 ethic
# 28 eugen
# 19 europ
# 18 european
# 19 eva
# 13 evan
# 48 eve
# 1801 even
# 252 event
# 176 eventu
# 523 ever
# 23 everett
# 664 everi
# 46 everybodi
# 23 everyday
# 350 everyon
# 371 everyth
# 34 everywher
# 68 evid
# 280 evil
# 25 evok
# 15 evolut
# 22 ewan
# 108 ex
# 251 exact
# 24 exagger
# 43 examin
# 231 exampl
# 14 exceed
# 153 excel
# 269 except
# 57 excess
# 51 exchang
# 188 excit
# 21 exclus
# 17 excruci
# 66 excus
# 18 exec
# 120 execut
# 49 exercis
# 16 exhaust
# 18 exhibit
# 165 exist
# 34 existenz
# 23 exit
# 18 exorcist
# 16 exot
# 17 exotica
# 20 expand
# 399 expect
# 17 expedit
# 47 expens
# 233 experi
# 39 experienc
# 13 experiment
# 40 expert
# 187 explain
# 59 explan
# 26 explicit
# 35 explod
# 64 exploit
# 116 explor
# 73 explos
# 37 expos
# 13 exposit
# 111 express
# 15 exquisit
# 45 extend
# 22 extens
# 27 extent
# 13 extermin
# 69 extra
# 33 extraordinari
# 17 extraterrestri
# 236 extrem
# 357 eye
# 28 fabl
# 18 fabric
# 22 fabul
# 383 face
# 21 facial
# 13 facil
# 620 fact
# 43 factor
# 25 factori
# 20 fade
# 255 fail
# 68 failur
# 182 fair
# 34 fairi
# 83 faith
# 70 fake
# 397 fall
# 49 fallen
# 36 fals
# 63 fame
# 520 famili
# 142 familiar
# 85 famous
# 295 fan
# 20 fanat
# 32 fanci
# 99 fantasi
# 72 fantast
# 459 far
# 17 farc
# 70 fare
# 32 fargo
# 17 farley
# 28 farm
# 13 farmer
# 25 farrelli
# 13 fart
# 98 fascin
# 13 fascist
# 111 fashion
# 149 fast
# 62 fat
# 38 fatal
# 78 fate
# 351 father
# 74 fault
# 47 favor
# 131 favorit
# 13 favourit
# 77 fbi
# 148 fear
# 21 feat
# 432 featur
# 27 fed
# 33 feder
# 23 feed
# 704 feel
# 50 feet
# 18 fei
# 38 felix
# 27 fell
# 16 fellini
# 71 fellow
# 125 felt
# 96 femal
# 12 feminist
# 14 femm
# 14 fenc
# 12 fern
# 13 feroci
# 13 ferri
# 16 fest
# 38 festiv
# 17 fetch
# 12 fetish
# 12 fever
# 106 fi
# 31 fianc
# 19 fiance
# 181 fiction
# 15 fidel
# 77 field
# 39 fienn
# 49 fifteen
# 34 fifth
# 18 fifti
# 305 fight
# 34 fighter
# 211 figur
# 78 file
# 206 fill
# 7916 film
# 252 filmmak
# 611 final
# 34 financi
# 25 fincher
# 861 find
# 210 fine
# 43 finest
# 38 finger
# 12 fingernail
# 70 finish
# 26 finn
# 12 fiorentino
# 145 fire
# 37 firm
# 1255 first
# 62 fish
# 18 fishburn
# 16 fisher
# 13 fisherman
# 19 fist
# 102 fit
# 209 five
# 23 fix
# 23 flair
# 23 flame
# 15 flander
# 63 flash
# 79 flashback
# 31 flashi
# 93 flat
# 17 flavor
# 164 flaw
# 32 flawless
# 28 flee
# 52 flesh
# 141 fli
# 197 flick
# 35 flight
# 16 flip
# 23 flirt
# 47 float
# 18 flood
# 88 floor
# 20 flop
# 16 florida
# 19 flourish
# 41 flow
# 14 flower
# 24 flubber
# 25 fluff
# 47 flynt
# 169 focus
# 13 fodder
# 14 foil
# 26 foley
# 62 folk
# 410 follow
# 25 fond
# 34 fonda
# 83 food
# 47 fool
# 15 foolish
# 52 foot
# 84 footag
# 45 footbal
# 376 forc
# 72 ford
# 53 foreign
# 12 foreshadow
# 31 forest
# 66 forev
# 15 forewarn
# 115 forget
# 22 forgett
# 38 forgiv
# 21 forgot
# 52 forgotten
# 13 forlani
# 194 form
# 27 format
# 151 former
# 106 formula
# 20 forrest
# 18 fort
# 33 forth
# 28 forti
# 71 fortun
# 64 forward
# 44 foster
# 13 fought
# 36 foul
# 297 found
# 205 four
# 30 fourth
# 88 fox
# 94 frame
# 38 franc
# 29 franchis
# 41 franci
# 16 francisco
# 174 frank
# 31 frankenstein
# 15 franki
# 19 franklin
# 23 frantic
# 19 fraser
# 32 freak
# 23 fred
# 45 freddi
# 121 free
# 47 freedom
# 45 freeman
# 44 freez
# 102 french
# 18 frenzi
# 30 frequenc
# 67 frequent
# 81 fresh
# 19 fri
# 20 friday
# 593 friend
# 37 friendship
# 26 fright
# 109 frighten
# 17 frog
# 104 front
# 13 frozen
# 46 frustrat
# 40 fu
# 21 fuck
# 20 fuel
# 45 fugit
# 38 fulfil
# 274 full
# 28 fuller
# 66 fulli
# 386 fun
# 35 function
# 30 fund
# 22 fundament
# 27 funer
# 567 funni
# 20 funnier
# 50 funniest
# 14 furi
# 17 furious
# 12 furthermor
# 175 futur
# 21 futurist
# 30 gabriel
# 38 gadget
# 98 gag
# 64 gain
# 19 gal
# 22 galaxi
# 14 gale
# 13 galor
# 34 gambl
# 282 game
# 67 gang
# 65 gangster
# 20 gap
# 14 gape
# 32 garbag
# 13 garcia
# 30 garden
# 46 gari
# 18 garner
# 30 garofalo
# 12 garth
# 28 gas
# 18 gate
# 36 gather
# 32 gattaca
# 16 gaug
# 99 gave
# 79 gay
# 18 gayheart
# 29 gear
# 13 gee
# 20 geek
# 14 gellar
# 29 gem
# 28 gene
# 232 general
# 168 generat
# 40 generic
# 13 generous
# 35 genet
# 54 genius
# 208 genr
# 26 gentl
# 14 gentleman
# 104 genuin
# 23 geoffrey
# 166 georg
# 21 georgia
# 22 gerard
# 40 gere
# 41 german
# 15 geronimo
# 12 gerri
# 13 gestur
# 2207 get
# 17 ghetto
# 84 ghost
# 12 ghostbust
# 116 giant
# 80 gibson
# 52 gift
# 17 giggl
# 22 gimmick
# 491 girl
# 168 girlfriend
# 893 give
# 330 given
# 32 glad
# 12 gladiat
# 16 glamor
# 33 glanc
# 18 glare
# 40 glass
# 22 glen
# 34 glenn
# 24 glimps
# 17 globe
# 13 gloomi
# 31 glori
# 29 gloria
# 22 glorious
# 14 glover
# 19 glow
# 1418 go
# 74 goal
# 181 god
# 29 godfath
# 85 godzilla
# 467 goe
# 17 goer
# 53 gold
# 20 goldberg
# 21 goldblum
# 41 golden
# 19 gon
# 136 gone
# 41 gonna
# 18 goo
# 1670 good
# 12 goodby
# 17 goodfella
# 36 goodman
# 58 goofi
# 15 goon
# 22 gordi
# 39 gordon
# 81 gore
# 33 gorgeous
# 36 gori
# 35 gorilla
# 331 got
# 21 gothic
# 45 gotten
# 117 govern
# 35 grab
# 119 grace
# 41 grade
# 14 gradi
# 33 gradual
# 36 graduat
# 26 graham
# 12 graini
# 67 grand
# 17 grandfath
# 20 grandmoth
# 30 granger
# 114 grant
# 70 graphic
# 23 grasp
# 20 grate
# 34 gratuit
# 29 grave
# 12 graviti
# 15 gray
# 849 great
# 38 greater
# 92 greatest
# 24 greed
# 91 green
# 16 greenwood
# 16 greet
# 33 greg
# 21 grew
# 22 grier
# 16 griffin
# 34 griffith
# 29 grim
# 14 grin
# 14 grinch
# 33 grip
# 29 grisham
# 12 griswold
# 22 gritti
# 16 groan
# 14 groceri
# 12 groeteschel
# 70 gross
# 106 ground
# 15 groundhog
# 290 group
# 167 grow
# 50 grown
# 20 gruesom
# 13 gruff
# 12 grumpi
# 16 grunt
# 30 guarante
# 84 guard
# 13 guardian
# 201 guess
# 47 guest
# 35 guid
# 12 guidanc
# 27 guilt
# 53 guilti
# 13 gump
# 179 gun
# 18 gus
# 33 gut
# 672 guy
# 14 gwen
# 21 gwyneth
# 21 ha
# 26 habit
# 44 hack
# 14 hacker
# 20 hackman
# 13 hackney
# 28 hadn
# 16 hail
# 85 hair
# 365 half
# 37 halfway
# 73 hall
# 51 halloween
# 22 ham
# 31 hamlet
# 28 hammer
# 21 hammond
# 17 han
# 441 hand
# 114 handl
# 29 handsom
# 91 hang
# 119 hank
# 18 hannah
# 26 hapless
# 514 happen
# 184 happi
# 23 happili
# 13 har
# 19 harbor
# 506 hard
# 15 hardcor
# 25 harder
# 17 harlem
# 19 harm
# 13 harmless
# 16 harold
# 35 harrelson
# 158 harri
# 32 harrison
# 14 harrow
# 28 harsh
# 14 hart
# 12 harvard
# 15 harvey
# 63 hasn
# 27 hat
# 160 hate
# 15 hatr
# 105 haunt
# 104 haven
# 17 havoc
# 28 hawk
# 25 hayek
# 424 head
# 17 headach
# 12 headlin
# 13 heal
# 13 healthi
# 20 heap
# 149 hear
# 120 heard
# 269 heart
# 19 heartbreak
# 12 heartfelt
# 31 heat
# 29 heather
# 64 heaven
# 104 heavi
# 52 heavili
# 23 hech
# 29 heck
# 14 heckerl
# 13 hedwig
# 17 heel
# 21 height
# 16 heighten
# 27 heist
# 45 held
# 66 helen
# 15 helicopt
# 173 hell
# 24 helm
# 475 help
# 16 helpless
# 19 hen
# 23 henc
# 69 henri
# 31 henstridg
# 21 hereaft
# 13 herman
# 260 hero
# 21 heroic
# 53 heroin
# 17 hesit
# 19 heston
# 24 hewitt
# 53 hey
# 13 heyst
# 57 hidden
# 61 hide
# 20 hideous
# 550 high
# 34 higher
# 18 highest
# 13 highland
# 54 highlight
# 22 highway
# 169 hilari
# 109 hill
# 67 hint
# 53 hip
# 83 hire
# 55 histor
# 153 histori
# 295 hit
# 42 hitchcock
# 15 hitman
# 32 ho
# 35 hoffman
# 22 hokey
# 189 hold
# 96 hole
# 30 holi
# 33 holiday
# 12 holli
# 46 hollow
# 417 hollywood
# 33 holm
# 17 holocaust
# 41 homag
# 421 home
# 17 homer
# 14 hometown
# 25 homicid
# 32 homosexu
# 88 honest
# 13 honesti
# 12 honey
# 77 hong
# 46 honor
# 30 hood
# 59 hook
# 15 hooker
# 12 hoot
# 27 hop
# 351 hope
# 34 hopeless
# 46 hopkin
# 23 hopper
# 41 horizon
# 13 hormon
# 18 horn
# 15 horner
# 20 horni
# 12 horrend
# 97 horribl
# 23 horrif
# 37 horrifi
# 351 horror
# 70 hors
# 12 horseman
# 77 hospit
# 43 host
# 26 hostag
# 12 hostil
# 89 hot
# 68 hotel
# 14 hotshot
# 444 hour
# 294 hous
# 16 household
# 45 howard
# 714 howev
# 13 howi
# 22 hudson
# 134 huge
# 65 hugh
# 18 hugo
# 21 huh
# 13 hulot
# 17 hum
# 483 human
# 16 humbert
# 23 humili
# 362 humor
# 58 humour
# 66 hundr
# 17 hungri
# 102 hunt
# 61 hunter
# 12 hurley
# 16 hurrican
# 54 hurt
# 175 husband
# 19 hush
# 13 hustler
# 15 hyde
# 45 hype
# 12 hyper
# 13 hypnot
# 19 hyster
# 40 ian
# 74 ice
# 17 iceberg
# 27 icon
# 25 id
# 369 idea
# 53 ideal
# 74 ident
# 43 identifi
# 20 ideolog
# 62 idiot
# 19 idl
# 13 idol
# 69 ignor
# 114 ii
# 30 iii
# 56 ill
# 25 illeg
# 18 illog
# 31 illustr
# 165 imag
# 34 imageri
# 218 imagin
# 21 imit
# 124 immedi
# 34 immens
# 19 immers
# 19 immort
# 119 impact
# 14 imperi
# 21 imperson
# 31 implaus
# 19 impli
# 226 import
# 19 impos
# 133 imposs
# 283 impress
# 23 imprison
# 58 improv
# 16 improvis
# 15 in
# 18 inabl
# 40 inan
# 13 inappropri
# 18 incarn
# 23 incess
# 16 inch
# 34 incid
# 17 incident
# 432 includ
# 17 incoher
# 26 incompet
# 19 incomprehens
# 26 inconsist
# 22 incorpor
# 62 increas
# 157 incred
# 91 inde
# 89 independ
# 26 indi
# 40 indian
# 21 indiana
# 19 indic
# 89 individu
# 35 induc
# 29 indulg
# 74 industri
# 15 ineffect
# 38 inept
# 61 inevit
# 28 inexplic
# 35 infam
# 17 inferior
# 15 infinit
# 50 influenc
# 120 inform
# 14 ingeni
# 18 ingredi
# 33 inhabit
# 25 inher
# 15 inherit
# 85 initi
# 33 inject
# 16 injuri
# 19 inmat
# 32 inner
# 113 innoc
# 27 innov
# 56 insan
# 17 insect
# 18 insecur
# 28 insert
# 120 insid
# 73 insight
# 16 insipid
# 29 insist
# 29 inspector
# 142 inspir
# 50 instal
# 69 instanc
# 43 instant
# 411 instead
# 57 instinct
# 25 institut
# 17 instrument
# 66 insult
# 27 insur
# 18 insurrect
# 24 integr
# 56 intellectu
# 242 intellig
# 83 intend
# 112 intens
# 95 intent
# 74 interact
# 715 interest
# 14 interior
# 68 intern
# 25 internet
# 32 interpret
# 23 interrupt
# 64 interview
# 13 intim
# 26 intric
# 95 intrigu
# 136 introduc
# 20 introduct
# 13 intrus
# 22 invad
# 15 invas
# 80 invent
# 30 invest
# 124 investig
# 40 invis
# 43 invit
# 451 involv
# 14 iq
# 13 ireland
# 37 irish
# 93 iron
# 31 ironi
# 13 ironsid
# 25 irrelev
# 17 irresist
# 48 irrit
# 13 irv
# 13 ish
# 102 island
# 584 isn
# 41 isol
# 119 issu
# 40 italian
# 17 item
# 20 ivi
# 188 jack
# 46 jackal
# 18 jacket
# 198 jacki
# 70 jackson
# 15 jacob
# 15 jacqu
# 59 jail
# 34 jake
# 28 jakob
# 302 jame
# 33 jami
# 38 jan
# 66 jane
# 18 janean
# 20 janet
# 13 januari
# 22 japan
# 61 japanes
# 52 jar
# 75 jason
# 52 jaw
# 30 jawbreak
# 62 jay
# 18 jazz
# 25 jealous
# 74 jean
# 14 jeann
# 43 jedi
# 82 jeff
# 25 jeffrey
# 15 jenni
# 71 jennif
# 22 jeopardi
# 21 jeremi
# 29 jerk
# 17 jerom
# 106 jerri
# 16 jersey
# 14 jess
# 20 jessica
# 40 jesus
# 35 jet
# 23 jew
# 19 jewish
# 19 jill
# 136 jim
# 71 jimmi
# 19 jo
# 61 joan
# 427 job
# 22 joblo
# 23 jock
# 16 jodi
# 220 joe
# 41 joel
# 16 joey
# 568 john
# 52 johnni
# 38 johnson
# 113 join
# 13 joint
# 271 joke
# 26 joker
# 40 joli
# 48 jon
# 49 jonathan
# 166 jone
# 32 jordan
# 16 joseph
# 24 josh
# 19 josi
# 24 journalist
# 78 journey
# 13 jovovich
# 53 joy
# 86 jr
# 37 judd
# 29 jude
# 82 judg
# 13 judgement
# 20 judgment
# 20 judi
# 16 judith
# 15 juggl
# 96 juli
# 86 julia
# 17 juliann
# 18 juliet
# 13 juliett
# 107 jump
# 47 jungl
# 13 junior
# 17 junk
# 19 junki
# 39 jurass
# 16 juri
# 41 justic
# 34 justifi
# 15 justin
# 15 juvenil
# 17 kane
# 40 karen
# 13 karla
# 76 kate
# 18 kathi
# 21 kathleen
# 21 kati
# 13 kaufman
# 27 kay
# 32 keanu
# 40 keaton
# 13 keener
# 426 keep
# 13 keitel
# 47 kelli
# 19 ken
# 24 kennedi
# 39 kenneth
# 13 kenni
# 13 kenobi
# 68 kept
# 17 kersey
# 212 kevin
# 104 key
# 93 kick
# 406 kid
# 13 kidman
# 103 kidnap
# 20 kidnapp
# 500 kill
# 249 killer
# 41 kilmer
# 23 kim
# 18 kimbl
# 445 kind
# 29 kinda
# 211 king
# 13 kingdom
# 17 kingpin
# 17 kingsley
# 86 kiss
# 18 kit
# 14 kitchen
# 15 kitti
# 13 klein
# 30 kline
# 79 knew
# 17 knife
# 49 knight
# 85 knock
# 1104 know
# 47 knowledg
# 223 known
# 64 kong
# 28 krippendorf
# 14 ku
# 28 kubrick
# 18 kudo
# 18 kudrow
# 37 kung
# 19 kurt
# 17 kurtz
# 80 la
# 18 lab
# 26 label
# 39 labor
# 17 labut
# 17 lace
# 298 lack
# 13 lacklust
# 78 ladi
# 18 laid
# 36 lake
# 16 lamb
# 16 lambeau
# 17 lambert
# 83 lame
# 26 lanc
# 129 land
# 21 landscap
# 25 lane
# 23 lang
# 98 languag
# 19 lara
# 184 larg
# 34 larger
# 52 larri
# 43 las
# 637 last
# 186 late
# 276 later
# 137 latest
# 82 latter
# 437 laugh
# 76 laughabl
# 34 laughter
# 23 launch
# 33 laura
# 13 lauren
# 15 laurenc
# 18 lauri
# 16 lavish
# 157 law
# 60 lawrenc
# 94 lawyer
# 30 lay
# 21 layer
# 25 lazi
# 428 lead
# 99 leader
# 52 leagu
# 30 lean
# 38 leap
# 18 leari
# 258 learn
# 481 least
# 18 leather
# 397 leav
# 53 lebowski
# 19 lectur
# 78 led
# 22 leder
# 174 lee
# 289 left
# 50 leg
# 33 legal
# 102 legend
# 36 legendari
# 30 leigh
# 31 leila
# 19 lemmon
# 40 lend
# 87 length
# 15 lengthi
# 39 leo
# 25 leonard
# 20 leonardo
# 20 leoni
# 24 les
# 28 lesbian
# 23 lesli
# 353 less
# 17 lesser
# 31 lesson
# 16 lester
# 370 let
# 34 lethal
# 46 letter
# 223 level
# 16 levi
# 44 lewi
# 27 li
# 34 liam
# 21 liar
# 25 libbi
# 30 liber
# 144 lie
# 17 lieuten
# 1123 life
# 34 lifeless
# 21 lifestyl
# 18 lifetim
# 36 lift
# 217 light
# 13 lightheart
# 13 lightn
# 56 likabl
# 2929 like
# 37 likeabl
# 17 lili
# 14 limb
# 92 limit
# 13 limp
# 27 linda
# 16 lindo
# 543 line
# 70 liner
# 24 linger
# 37 link
# 33 lion
# 34 lip
# 23 lisa
# 110 list
# 69 listen
# 17 lit
# 88 liter
# 15 literari
# 15 literatur
# 1066 littl
# 12 liu
# 707 live
# 28 liz
# 14 lizard
# 413 ll
# 35 lloyd
# 49 load
# 25 loath
# 147 local
# 75 locat
# 34 lock
# 12 locker
# 69 logic
# 14 lola
# 17 lolita
# 42 london
# 71 lone
# 15 loneli
# 584 long
# 87 longer
# 12 longtim
# 1358 look
# 74 loos
# 22 lopez
# 57 lord
# 38 los
# 173 lose
# 41 loser
# 42 loss
# 288 lost
# 588 lot
# 27 lou
# 83 loud
# 17 loui
# 12 loung
# 21 lousi
# 23 lovabl
# 1011 love
# 111 lover
# 13 lovitz
# 139 low
# 24 lower
# 32 loyal
# 15 loyalti
# 12 lt
# 15 luc
# 64 luca
# 35 luci
# 15 lucinda
# 48 luck
# 51 lucki
# 35 luckili
# 30 ludicr
# 20 lui
# 39 luke
# 20 lumet
# 16 lure
# 19 lush
# 19 lust
# 17 luxuri
# 57 lynch
# 26 lyric
# 13 macdowel
# 116 machin
# 20 macho
# 26 maci
# 99 mad
# 761 made
# 15 madison
# 18 madonna
# 16 madsen
# 32 mafia
# 39 magazin
# 24 maggi
# 107 magic
# 13 magnet
# 28 magnific
# 16 magnolia
# 19 maguir
# 18 maid
# 42 mail
# 339 main
# 30 mainstream
# 56 maintain
# 253 major
# 2228 make
# 61 maker
# 29 makeup
# 28 malcolm
# 82 male
# 23 malick
# 27 malkovich
# 19 mall
# 14 mama
# 23 mamet
# 1037 man
# 346 manag
# 18 mandingo
# 12 maneuv
# 16 manhattan
# 923 mani
# 23 maniac
# 22 manic
# 63 manipul
# 22 mankind
# 12 mann
# 98 manner
# 27 mansion
# 18 manufactur
# 18 map
# 124 mar
# 28 marc
# 19 march
# 17 margaret
# 19 margin
# 94 mari
# 15 maria
# 24 marin
# 12 marit
# 162 mark
# 76 market
# 15 marlon
# 178 marri
# 65 marriag
# 45 marshal
# 34 martha
# 29 marti
# 35 martial
# 20 martian
# 119 martin
# 62 marvel
# 58 mask
# 38 mass
# 12 massacr
# 29 massiv
# 140 master
# 16 mastermind
# 63 masterpiec
# 80 match
# 15 matchmak
# 33 mate
# 177 materi
# 22 matilda
# 12 matine
# 71 matrix
# 62 matt
# 299 matter
# 17 matthau
# 89 matthew
# 53 matur
# 99 max
# 22 maximum
# 616 may
# 257 mayb
# 17 mayhem
# 20 mayor
# 28 mcconaughey
# 19 mcdonald
# 25 mcgowan
# 33 mcgregor
# 12 mckellar
# 14 mctiernan
# 15 meal
# 358 mean
# 14 meander
# 13 meaning
# 15 meaningless
# 66 meant
# 85 meanwhil
# 35 measur
# 30 meat
# 45 mechan
# 50 media
# 37 medic
# 58 mediocr
# 25 medium
# 347 meet
# 42 meg
# 64 mel
# 17 melani
# 21 melodrama
# 28 melodramat
# 14 melt
# 31 melvin
# 198 member
# 108 memor
# 87 memori
# 25 memphi
# 374 men
# 95 menac
# 74 mental
# 172 mention
# 20 mentor
# 12 mercenari
# 16 merchandis
# 15 merci
# 12 merciless
# 20 mercuri
# 150 mere
# 27 merit
# 23 mermaid
# 13 merton
# 22 mesmer
# 120 mess
# 133 messag
# 18 messeng
# 49 met
# 33 metal
# 28 metaphor
# 14 meteor
# 47 method
# 24 mexico
# 31 meyer
# 16 mia
# 22 miami
# 297 michael
# 17 michel
# 33 michell
# 28 mickey
# 41 mid
# 160 middl
# 45 midnight
# 22 midst
# 461 might
# 28 mighti
# 74 mike
# 58 mild
# 61 mile
# 77 militari
# 19 milk
# 25 mill
# 13 millennium
# 55 miller
# 163 million
# 32 millionair
# 15 milton
# 16 mimi
# 13 mimic
# 396 mind
# 26 mindless
# 63 mine
# 14 mini
# 22 minim
# 15 minimum
# 13 minist
# 14 minni
# 113 minor
# 592 minut
# 14 miracl
# 22 miracul
# 18 miramax
# 45 mirror
# 21 miscast
# 57 miser
# 20 miseri
# 20 misguid
# 242 miss
# 19 missil
# 168 mission
# 75 mistak
# 32 mistaken
# 31 mitchel
# 117 mix
# 15 mixtur
# 42 mm
# 13 mo
# 52 mob
# 24 mobster
# 32 mock
# 16 mod
# 18 mode
# 79 model
# 19 moder
# 110 modern
# 13 modest
# 15 modin
# 19 mohr
# 17 mold
# 16 molli
# 39 mom
# 534 moment
# 24 momentum
# 26 momma
# 17 mona
# 364 money
# 22 monica
# 62 monkey
# 16 monologu
# 14 monoton
# 119 monster
# 13 monstrous
# 22 montag
# 17 montana
# 115 month
# 24 monti
# 77 mood
# 14 moodi
# 19 moon
# 62 moor
# 108 moral
# 17 moreau
# 34 morgan
# 42 morn
# 29 moron
# 13 morri
# 17 morrison
# 14 mors
# 29 mortal
# 12 mortensen
# 16 mose
# 178 most
# 16 motel
# 301 mother
# 149 motion
# 79 motiv
# 15 motorcycl
# 12 mount
# 48 mountain
# 39 mous
# 102 mouth
# 385 move
# 45 movement
# 4920 movi
# 23 moviego
# 13 moviemak
# 195 mr
# 63 mrs
# 55 ms
# 33 mtv
# 1455 much
# 13 muddl
# 14 mug
# 45 mulan
# 34 mulder
# 34 multi
# 40 multipl
# 17 mummi
# 15 mundan
# 326 murder
# 14 muriel
# 13 murki
# 125 murphi
# 35 murray
# 14 muscl
# 23 muse
# 23 museum
# 436 music
# 25 musician
# 28 musket
# 411 must
# 15 muster
# 14 mutat
# 33 myer
# 219 mysteri
# 27 mystic
# 20 mythic
# 13 mytholog
# 13 naboo
# 28 nail
# 24 naiv
# 58 nake
# 630 name
# 149 narrat
# 14 narrow
# 25 nasa
# 63 nasti
# 22 natali
# 36 natasha
# 72 nation
# 32 nativ
# 268 natur
# 44 nazi
# 58 nbsp
# 19 nc
# 15 neal
# 351 near
# 24 nearbi
# 35 neat
# 66 necessari
# 38 necessarili
# 23 neck
# 21 ned
# 451 need
# 31 needless
# 38 neeson
# 42 negat
# 14 neglect
# 20 negoti
# 60 neighbor
# 21 neighborhood
# 40 neil
# 111 neither
# 24 nello
# 30 nelson
# 15 nemesi
# 22 neo
# 19 nerd
# 28 nerv
# 32 nervous
# 14 ness
# 14 net
# 33 network
# 15 neurot
# 26 neve
# 952 never
# 43 nevertheless
# 877 new
# 27 newcom
# 16 newest
# 25 newli
# 25 newman
# 74 news
# 18 newspap
# 21 newton
# 301 next
# 13 niccol
# 314 nice
# 23 nichola
# 42 nicholson
# 110 nick
# 19 nicki
# 14 nicknam
# 19 nicol
# 19 nicola
# 19 nielsen
# 25 nifti
# 15 nigel
# 395 night
# 18 nightclub
# 58 nightmar
# 13 nihilist
# 15 nikki
# 13 nina
# 47 nine
# 20 nineti
# 32 niro
# 18 nixon
# 22 nobl
# 65 nobodi
# 16 nod
# 45 noir
# 23 nois
# 27 nolt
# 85 nomin
# 98 non
# 174 none
# 43 nonetheless
# 35 nonsens
# 13 noon
# 14 norm
# 103 normal
# 17 norman
# 33 north
# 28 norton
# 29 nose
# 13 nostalg
# 27 nostalgia
# 16 not
# 74 notabl
# 33 notch
# 228 note
# 16 noteworthi
# 541 noth
# 130 notic
# 39 notion
# 18 notori
# 204 novel
# 12 novelist
# 19 nowaday
# 75 nowher
# 57 nuclear
# 23 nude
# 54 nuditi
# 19 numb
# 201 number
# 72 numer
# 31 nurs
# 14 nut
# 26 obi
# 72 object
# 33 obligatori
# 12 oblivi
# 38 obnoxi
# 17 obscen
# 28 obscur
# 64 observ
# 122 obsess
# 24 obstacl
# 16 obtain
# 377 obvious
# 32 occas
# 118 occasion
# 17 occupi
# 108 occur
# 15 occurr
# 45 ocean
# 20 octob
# 165 odd
# 17 odyssey
# 16 offbeat
# 30 offend
# 63 offens
# 228 offer
# 256 offic
# 39 offici
# 249 often
# 166 oh
# 25 oil
# 61 ok
# 98 okay
# 14 ol
# 605 old
# 76 older
# 17 oldman
# 51 oliv
# 23 omin
# 4214 one
# 13 onegin
# 13 ongo
# 13 onofrio
# 22 onscreen
# 75 onto
# 20 ooz
# 500 open
# 83 oper
# 45 opera
# 87 opinion
# 13 oppon
# 116 opportun
# 31 oppos
# 70 opposit
# 22 oppress
# 22 opt
# 16 option
# 17 orang
# 28 ordel
# 239 order
# 47 ordinari
# 68 organ
# 13 orgi
# 21 orient
# 609 origin
# 18 orphan
# 200 oscar
# 15 osmosi
# 204 other
# 105 otherwis
# 13 ounc
# 17 out
# 20 outcom
# 23 outer
# 26 outfit
# 18 outing
# 14 outlandish
# 15 outlin
# 51 outrag
# 19 outset
# 121 outsid
# 52 outstand
# 58 over
# 26 overact
# 120 overal
# 22 overbear
# 14 overblown
# 43 overcom
# 22 overdon
# 17 overlong
# 24 overlook
# 14 overplay
# 16 overshadow
# 15 overus
# 28 overwhelm
# 25 owe
# 25 owen
# 40 own
# 75 owner
# 30 oz
# 186 pace
# 19 pacino
# 72 pack
# 27 packag
# 19 pad
# 32 page
# 39 paid
# 159 pain
# 79 paint
# 94 pair
# 18 pal
# 14 palac
# 17 pale
# 26 palma
# 15 palmer
# 18 palmetto
# 12 palminteri
# 13 palpabl
# 37 paltrow
# 30 pam
# 30 pan
# 16 panic
# 23 pant
# 39 paper
# 28 par
# 19 parad
# 25 paradis
# 14 paragraph
# 38 parallel
# 16 paramount
# 14 paranoia
# 21 paranoid
# 169 parent
# 43 pari
# 129 park
# 34 parker
# 74 parodi
# 24 parol
# 667 part
# 145 parti
# 16 partial
# 30 particip
# 288 particular
# 100 partner
# 167 pass
# 33 passeng
# 61 passion
# 251 past
# 28 pat
# 64 patch
# 53 path
# 76 pathet
# 14 patienc
# 76 patient
# 14 patlabor
# 15 patricia
# 61 patrick
# 14 patriot
# 22 pattern
# 184 paul
# 24 pauli
# 29 paxton
# 172 pay
# 23 payback
# 16 paycheck
# 22 payoff
# 42 peac
# 31 peak
# 15 peculiar
# 17 peel
# 15 peer
# 30 pen
# 31 penn
# 17 penni
# 1069 peopl
# 19 pepper
# 22 per
# 13 percept
# 385 perfect
# 1069 perform
# 14 perfunctori
# 310 perhap
# 13 peril
# 101 period
# 18 perman
# 21 perpetu
# 36 perri
# 514 person
# 36 persona
# 49 perspect
# 14 persuad
# 16 pervers
# 28 pet
# 16 pete
# 200 peter
# 16 petti
# 15 pfeiffer
# 68 pg
# 57 phantom
# 16 phenomen
# 19 phenomenon
# 45 phil
# 25 philip
# 34 phillip
# 19 phillipp
# 28 philosoph
# 25 philosophi
# 14 phoenix
# 66 phone
# 20 phoni
# 27 photo
# 34 photograph
# 40 photographi
# 35 phrase
# 90 physic
# 22 piano
# 13 pic
# 13 picard
# 152 pick
# 479 pictur
# 58 pie
# 256 piec
# 23 pierc
# 15 pierr
# 62 pig
# 39 pile
# 19 pill
# 60 pilot
# 30 pimp
# 16 pine
# 15 pink
# 14 pirat
# 20 piss
# 13 pit
# 37 pitch
# 27 piti
# 40 pitt
# 15 pivot
# 15 pixar
# 585 place
# 21 placement
# 26 plagu
# 52 plain
# 224 plan
# 77 plane
# 178 planet
# 30 plant
# 13 plastic
# 21 platt
# 31 plausibl
# 1717 play
# 102 player
# 106 pleas
# 46 pleasant
# 19 pleasantvill
# 68 pleasur
# 91 plenti
# 21 plight
# 19 plod
# 1160 plot
# 15 plotlin
# 17 plug
# 52 plus
# 30 pod
# 15 poem
# 19 poet
# 15 poetic
# 21 poetri
# 27 poignant
# 617 point
# 69 pointless
# 30 poison
# 13 poitier
# 29 poke
# 20 pokemon
# 23 poker
# 155 polic
# 13 policeman
# 15 polish
# 160 polit
# 17 politician
# 12 pollack
# 13 polley
# 30 ponder
# 23 pool
# 227 poor
# 117 pop
# 25 popcorn
# 50 popul
# 178 popular
# 55 porn
# 14 porno
# 15 pornograph
# 14 pornographi
# 30 porter
# 32 portion
# 23 portman
# 24 portrait
# 201 portray
# 28 pose
# 116 posit
# 87 possess
# 291 possibl
# 70 post
# 23 poster
# 27 postman
# 20 pot
# 18 potent
# 147 potenti
# 14 potter
# 25 pound
# 23 pour
# 17 powel
# 361 power
# 73 practic
# 36 prais
# 17 pray
# 37 pre
# 15 preach
# 18 preacher
# 21 preced
# 25 precious
# 38 precis
# 15 predat
# 39 predecessor
# 200 predict
# 51 prefer
# 33 pregnant
# 26 premier
# 168 premis
# 74 prepar
# 17 preposter
# 129 presenc
# 314 present
# 17 preserv
# 114 presid
# 77 press
# 21 pressur
# 12 preston
# 41 presum
# 46 pretend
# 31 pretenti
# 381 pretti
# 49 prevent
# 46 preview
# 176 previous
# 14 prey
# 61 price
# 17 pride
# 42 priest
# 31 primari
# 22 primarili
# 41 prime
# 44 princ
# 67 princess
# 27 princip
# 15 principl
# 33 print
# 35 prinz
# 32 prior
# 205 prison
# 118 privat
# 22 prize
# 14 pro
# 380 probabl
# 484 problem
# 13 procedur
# 74 proceed
# 75 process
# 27 proclaim
# 291 produc
# 321 product
# 30 profan
# 24 profess
# 72 profession
# 55 professor
# 22 profil
# 30 profit
# 31 profound
# 65 program
# 78 progress
# 177 project
# 21 prologu
# 16 prom
# 29 promin
# 145 promis
# 39 promot
# 17 prompt
# 18 pronounc
# 36 proof
# 12 propaganda
# 22 propel
# 46 proper
# 16 properti
# 16 proport
# 23 propos
# 16 prospect
# 28 prostitut
# 78 protagonist
# 59 protect
# 17 protest
# 33 proud
# 201 prove
# 16 proven
# 20 proverbi
# 275 provid
# 16 provoc
# 53 provok
# 25 pseudo
# 17 psych
# 20 psychiatrist
# 25 psychic
# 32 psychlo
# 52 psycho
# 56 psycholog
# 12 psychologist
# 12 psychopath
# 40 psychot
# 99 public
# 25 publish
# 199 pull
# 46 pulp
# 20 puls
# 24 pump
# 30 pun
# 67 punch
# 13 punctuat
# 35 punish
# 13 punk
# 13 pupil
# 15 puppet
# 21 puppi
# 13 purchas
# 88 pure
# 138 purpos
# 25 pursu
# 22 pursuit
# 65 push
# 422 put
# 28 puzzl
# 43 quaid
# 13 qualifi
# 170 qualiti
# 18 quarter
# 96 queen
# 30 quentin
# 46 quest
# 362 question
# 19 qui
# 282 quick
# 63 quiet
# 28 quinn
# 15 quirk
# 43 quirki
# 498 quit
# 16 quiz
# 31 quot
# 110 race
# 26 rachel
# 12 racial
# 28 racism
# 20 racist
# 12 radiant
# 12 radiat
# 17 radic
# 74 radio
# 37 rage
# 28 raider
# 25 raimi
# 62 rain
# 107 rais
# 26 ralph
# 14 rambl
# 20 ramsey
# 23 ran
# 31 randi
# 35 random
# 60 rang
# 14 ranger
# 35 rank
# 28 ransom
# 18 rant
# 20 rap
# 61 rape
# 41 rapid
# 142 rare
# 31 rat
# 299 rate
# 447 rather
# 20 ratio
# 19 ration
# 23 rave
# 22 raw
# 65 ray
# 787 re
# 14 rea
# 124 reach
# 23 react
# 53 reaction
# 208 read
# 20 reader
# 80 readi
# 14 reagan
# 658 real
# 24 realis
# 29 realism
# 107 realist
# 159 realiti
# 278 realiz
# 1128 realli
# 18 realm
# 15 reappear
# 445 reason
# 27 rebecca
# 25 rebel
# 14 reborn
# 44 recal
# 91 receiv
# 225 recent
# 16 recit
# 14 reckless
# 64 recogn
# 17 recognit
# 116 recommend
# 86 record
# 23 recov
# 34 recreat
# 26 recruit
# 16 recur
# 22 recycl
# 142 red
# 36 redeem
# 30 redempt
# 14 redford
# 24 redman
# 27 reduc
# 27 reel
# 25 rees
# 37 reev
# 127 refer
# 52 reflect
# 42 refresh
# 75 refus
# 52 regard
# 28 regardless
# 19 regist
# 26 regret
# 59 regular
# 23 rehash
# 20 reign
# 15 reindeer
# 32 reject
# 186 relat
# 318 relationship
# 17 relax
# 327 releas
# 13 releg
# 19 relentless
# 20 relev
# 67 reli
# 20 reliabl
# 62 relief
# 55 religi
# 35 religion
# 18 relish
# 48 reluct
# 186 remain
# 13 remaind
# 74 remak
# 104 remark
# 188 rememb
# 113 remind
# 48 reminisc
# 60 remot
# 57 remov
# 30 render
# 13 rendit
# 15 rene
# 13 renegad
# 13 reno
# 14 renown
# 77 rent
# 13 rental
# 60 repeat
# 32 repetit
# 87 replac
# 24 repli
# 109 report
# 58 repres
# 24 repris
# 14 repuls
# 33 reput
# 122 requir
# 105 rescu
# 41 research
# 76 resembl
# 18 resent
# 27 reserv
# 48 resid
# 32 resist
# 29 resolut
# 27 resolv
# 23 reson
# 28 resort
# 30 resourc
# 179 respect
# 26 respond
# 88 respons
# 334 rest
# 34 restaur
# 26 restor
# 17 restrain
# 19 restraint
# 258 result
# 15 resum
# 25 resurrect
# 18 retain
# 38 retir
# 21 retriev
# 13 retrospect
# 257 return
# 25 reunion
# 15 reunit
# 159 reveal
# 45 revel
# 66 reveng
# 18 revers
# 315 review
# 27 reviv
# 16 revolut
# 15 revolutionari
# 44 revolv
# 43 reward
# 14 reynold
# 16 reza
# 13 rhythm
# 19 ribisi
# 27 ricci
# 15 rice
# 129 rich
# 141 richard
# 19 richardson
# 41 rick
# 23 ricki
# 13 rickman
# 15 rico
# 22 rid
# 120 ride
# 147 ridicul
# 597 right
# 13 rimbaud
# 45 ring
# 19 riot
# 82 rip
# 60 ripley
# 120 rise
# 64 risk
# 15 riski
# 20 rita
# 16 ritual
# 57 rival
# 41 river
# 15 rivet
# 104 road
# 15 roar
# 88 rob
# 21 robber
# 29 robberi
# 34 robbi
# 34 robbin
# 278 robert
# 143 robin
# 15 robinson
# 44 robocop
# 64 robot
# 158 rock
# 57 rocki
# 20 rodriguez
# 72 roger
# 15 rogu
# 794 role
# 107 roll
# 15 roman
# 140 romanc
# 198 romant
# 30 romeo
# 13 romi
# 18 romp
# 34 ron
# 13 ronna
# 14 roof
# 13 rooki
# 214 room
# 48 roommat
# 78 root
# 77 rose
# 15 rosi
# 23 ross
# 34 roth
# 36 rough
# 53 round
# 13 rounder
# 16 rous
# 25 rout
# 60 routin
# 23 row
# 22 roy
# 19 royal
# 17 rubber
# 13 rude
# 23 rudi
# 20 rug
# 68 ruin
# 143 rule
# 25 rumbl
# 20 rumor
# 620 run
# 29 runner
# 83 rush
# 14 rushmor
# 69 russel
# 66 russian
# 20 ruthless
# 151 ryan
# 15 sabotag
# 14 sacrif
# 20 sacrific
# 147 sad
# 16 saddl
# 23 sadist
# 66 safe
# 29 safeti
# 18 saga
# 239 said
# 22 sail
# 21 saint
# 40 sake
# 29 sale
# 19 salesman
# 16 salli
# 20 salma
# 14 salvag
# 106 sam
# 20 sammi
# 14 sampl
# 19 samuel
# 12 samurai
# 32 san
# 20 sand
# 62 sandler
# 36 sandra
# 15 saniti
# 12 sant
# 13 santa
# 25 sappi
# 19 sara
# 48 sarah
# 14 sarandon
# 16 sarcast
# 32 sat
# 34 satan
# 13 satellit
# 96 satir
# 86 satisfi
# 33 saturday
# 30 savag
# 358 save
# 178 saw
# 812 say
# 60 scale
# 14 scam
# 18 scandal
# 12 scar
# 97 scare
# 140 scari
# 15 scarlett
# 12 scatter
# 33 scenario
# 1881 scene
# 34 sceneri
# 15 schedul
# 50 scheme
# 30 schindler
# 26 schneider
# 13 scholar
# 306 school
# 16 schrader
# 33 schumach
# 55 schwarzenegg
# 17 schwimmer
# 105 sci
# 169 scienc
# 13 scientif
# 89 scientist
# 177 score
# 48 scorses
# 103 scott
# 15 scottish
# 20 scratch
# 269 scream
# 578 screen
# 217 screenplay
# 173 screenwrit
# 51 screw
# 577 script
# 17 sculli
# 22 se
# 54 sea
# 45 seagal
# 14 seal
# 17 seamless
# 85 sean
# 122 search
# 73 season
# 85 seat
# 17 seattl
# 334 second
# 19 secondari
# 197 secret
# 18 secretari
# 31 section
# 69 secur
# 27 seduc
# 28 seduct
# 1566 see
# 56 seek
# 1358 seem
# 662 seen
# 69 segment
# 45 select
# 199 self
# 20 selfish
# 93 sell
# 36 semi
# 27 senat
# 115 send
# 20 senior
# 432 sens
# 17 sensat
# 16 senseless
# 30 sensibl
# 33 sensit
# 92 sent
# 35 sentenc
# 56 sentiment
# 73 separ
# 178 sequel
# 478 sequenc
# 13 serendip
# 400 seri
# 57 serial
# 293 serious
# 151 serv
# 59 servic
# 27 session
# 712 set
# 59 seth
# 55 settl
# 45 setup
# 74 seven
# 325 sever
# 332 sex
# 55 sexi
# 188 sexual
# 20 sgt
# 16 shade
# 20 shadi
# 57 shadow
# 24 shaft
# 25 shake
# 77 shakespear
# 20 shall
# 62 shallow
# 74 shame
# 17 shameless
# 23 shane
# 12 shanghai
# 13 shannon
# 43 shape
# 131 share
# 44 shark
# 28 sharon
# 50 sharp
# 24 shatter
# 17 shave
# 16 shaw
# 28 sheen
# 55 sheer
# 12 shelf
# 22 shell
# 18 shelv
# 37 sheriff
# 17 sherri
# 22 shi
# 21 shield
# 56 shift
# 74 shine
# 224 ship
# 32 shirt
# 24 shit
# 132 shock
# 25 shoe
# 168 shoot
# 56 shop
# 19 shore
# 255 short
# 12 shortcom
# 359 shot
# 13 shotgun
# 29 shoulder
# 57 shouldn
# 51 shout
# 967 show
# 36 showcas
# 33 showdown
# 30 shower
# 24 showgirl
# 90 shown
# 14 shrek
# 24 shue
# 31 shut
# 12 sibl
# 64 sick
# 14 sicken
# 25 sid
# 263 side
# 34 sidekick
# 54 sidney
# 16 sieg
# 109 sight
# 115 sign
# 19 signal
# 69 signific
# 14 sigourney
# 26 silenc
# 54 silent
# 118 silli
# 41 silver
# 20 silverston
# 166 similar
# 80 simon
# 217 simpl
# 307 simpli
# 19 simplist
# 17 simul
# 25 simultan
# 42 sin
# 512 sinc
# 35 sincer
# 112 sing
# 83 singer
# 158 singl
# 31 sinis
# 26 sinist
# 53 sink
# 30 sir
# 124 sister
# 192 sit
# 42 sitcom
# 32 site
# 226 situat
# 98 six
# 24 sixth
# 18 sixti
# 49 size
# 21 skeptic
# 31 sketch
# 93 skill
# 47 skin
# 35 skip
# 18 skit
# 23 skull
# 49 sky
# 23 skywalk
# 15 slacker
# 15 slade
# 20 slam
# 26 slap
# 47 slapstick
# 68 slasher
# 15 slater
# 19 slaughter
# 73 slave
# 27 slaveri
# 24 sleazi
# 78 sleep
# 25 sleepi
# 12 sleev
# 12 slew
# 22 sli
# 18 slice
# 30 slick
# 12 slicker
# 25 slide
# 135 slight
# 22 slightest
# 17 slim
# 13 slimi
# 40 slip
# 29 sloppi
# 158 slow
# 95 slowli
# 12 slug
# 14 smack
# 278 small
# 16 smaller
# 136 smart
# 13 smarter
# 32 smash
# 18 smell
# 68 smile
# 14 smirk
# 164 smith
# 15 smithe
# 65 smoke
# 30 smooth
# 77 snake
# 19 snap
# 16 snatch
# 37 sneak
# 35 snipe
# 34 snow
# 17 snuff
# 14 soak
# 37 soap
# 14 soar
# 81 social
# 116 societi
# 48 soft
# 12 soil
# 21 sold
# 89 soldier
# 68 sole
# 118 solid
# 23 solut
# 44 solv
# 29 somebodi
# 140 somehow
# 285 someon
# 765 someth
# 201 sometim
# 125 somewhat
# 94 somewher
# 227 son
# 184 song
# 45 sonni
# 275 soon
# 35 sophist
# 12 sophomor
# 18 sore
# 47 sorri
# 224 sort
# 26 sorvino
# 96 soul
# 316 sound
# 109 soundtrack
# 12 soup
# 14 sour
# 51 sourc
# 54 south
# 32 southern
# 18 soviet
# 222 space
# 14 spacecraft
# 16 spaceship
# 36 spacey
# 14 spade
# 18 spader
# 14 spain
# 22 span
# 20 spanish
# 31 spare
# 51 spark
# 78 spawn
# 173 speak
# 66 speci
# 412 special
# 53 specif
# 23 spectacl
# 73 spectacular
# 73 speech
# 83 speed
# 30 spell
# 18 spencer
# 198 spend
# 100 spent
# 12 spew
# 14 sphere
# 55 spi
# 65 spice
# 13 spider
# 103 spielberg
# 22 spike
# 18 spill
# 51 spin
# 113 spirit
# 34 spiritu
# 15 spit
# 24 spite
# 30 split
# 44 spoil
# 45 spoiler
# 39 spoken
# 25 spontan
# 37 spoof
# 12 spooki
# 24 spoon
# 56 sport
# 79 spot
# 14 spotlight
# 17 spout
# 27 spread
# 28 spring
# 13 sprinkl
# 36 squad
# 24 squar
# 22 st
# 41 stab
# 21 staff
# 129 stage
# 34 stahl
# 18 stake
# 25 stale
# 38 stalk
# 13 stall
# 53 stallon
# 23 stamp
# 242 stand
# 98 standard
# 22 standout
# 31 stanley
# 15 stapl
# 917 star
# 34 stare
# 18 stark
# 64 starship
# 539 start
# 29 startl
# 200 state
# 39 statement
# 76 station
# 44 status
# 196 stay
# 13 steadi
# 123 steal
# 21 steam
# 24 steel
# 21 stellar
# 116 step
# 78 stephen
# 95 stereotyp
# 25 stern
# 97 steve
# 119 steven
# 33 stewart
# 81 stick
# 20 stiff
# 15 stigmata
# 754 still
# 38 stiller
# 16 stilt
# 14 stimul
# 15 stink
# 30 stir
# 61 stock
# 13 stole
# 47 stolen
# 22 stomach
# 126 stone
# 16 stood
# 265 stop
# 98 store
# 1706 stori
# 50 storm
# 77 storylin
# 43 storytel
# 139 straight
# 25 straightforward
# 29 strain
# 31 strand
# 174 strang
# 42 stranger
# 13 strap
# 16 strategi
# 13 stray
# 160 street
# 67 strength
# 20 stress
# 76 stretch
# 47 strict
# 112 strike
# 46 string
# 53 strip
# 15 stripper
# 24 strive
# 15 stroke
# 207 strong
# 35 stronger
# 17 strongest
# 23 struck
# 57 structur
# 107 struggl
# 50 stuart
# 66 stuck
# 15 stud
# 127 student
# 81 studi
# 143 studio
# 18 stuf
# 150 stuff
# 54 stumbl
# 79 stun
# 72 stunt
# 228 stupid
# 257 style
# 37 stylish
# 18 stylist
# 60 sub
# 18 subdu
# 154 subject
# 109 subplot
# 27 subsequ
# 58 substanc
# 20 substanti
# 14 substitut
# 29 subtitl
# 95 subtl
# 29 subtleti
# 16 subway
# 110 succeed
# 350 success
# 77 suck
# 16 sucker
# 144 sudden
# 14 sue
# 150 suffer
# 20 suffic
# 111 suggest
# 73 suicid
# 118 suit
# 35 suitabl
# 16 sultri
# 47 sum
# 259 summer
# 34 sun
# 20 sunday
# 15 sunk
# 51 super
# 64 superb
# 17 superbl
# 33 superfici
# 18 supergirl
# 21 superhero
# 79 superior
# 21 superman
# 27 supernatur
# 12 superstar
# 31 suppli
# 247 support
# 339 suppos
# 19 suprem
# 394 sure
# 55 surfac
# 13 surpass
# 473 surpris
# 40 surreal
# 14 surrealist
# 17 surrog
# 80 surround
# 124 surviv
# 52 survivor
# 32 susan
# 129 suspect
# 22 suspend
# 206 suspens
# 28 suspici
# 16 suspicion
# 25 sustain
# 28 sutherland
# 16 suvari
# 12 suzi
# 23 swallow
# 30 swear
# 32 sweep
# 116 sweet
# 20 sweetheart
# 18 swim
# 22 swing
# 12 swinger
# 38 switch
# 31 sword
# 21 sylvest
# 59 symbol
# 21 sympath
# 56 sympathet
# 30 sympathi
# 13 syndrom
# 15 synopsi
# 29 synopsis
# 93 system
# 53 tabl
# 17 tack
# 22 tackl
# 22 tad
# 35 tag
# 13 taglin
# 1241 take
# 160 taken
# 166 tale
# 324 talent
# 331 talk
# 26 tall
# 14 tame
# 25 tango
# 18 tank
# 18 tap
# 40 tape
# 26 taran
# 72 tarantino
# 88 target
# 90 tarzan
# 72 task
# 63 tast
# 15 tasteless
# 13 tattoo
# 13 taught
# 21 tax
# 22 taxi
# 58 taylor
# 21 tea
# 50 teach
# 77 teacher
# 240 team
# 58 tear
# 22 tech
# 90 technic
# 37 techniqu
# 76 technolog
# 45 ted
# 13 teddi
# 35 tedious
# 145 teen
# 157 teenag
# 26 teeth
# 186 televis
# 518 tell
# 26 temper
# 19 templ
# 18 tempt
# 18 temptat
# 116 ten
# 53 tend
# 16 tendenc
# 20 tender
# 39 tens
# 103 tension
# 13 teri
# 12 terl
# 112 term
# 70 termin
# 12 terrenc
# 53 terri
# 139 terribl
# 87 terrif
# 44 terrifi
# 23 territori
# 82 terror
# 44 terrorist
# 100 test
# 43 texa
# 24 text
# 112 th
# 167 thank
# 226 theater
# 59 theatr
# 55 theatric
# 22 themat
# 177 theme
# 47 theori
# 14 therapi
# 12 thereaft
# 13 therebi
# 58 therefor
# 12 thereof
# 22 theron
# 28 thick
# 33 thief
# 95 thin
# 1156 thing
# 823 think
# 139 third
# 13 thirteen
# 30 thirteenth
# 52 thirti
# 68 thoma
# 28 thompson
# 18 thornton
# 56 thorough
# 653 though
# 368 thought
# 47 thousand
# 18 thread
# 44 threat
# 89 threaten
# 478 three
# 108 thrill
# 234 thriller
# 24 throat
# 14 throne
# 213 throughout
# 140 throw
# 14 throwaway
# 77 thrown
# 20 thrust
# 32 thug
# 20 thumb
# 35 thurman
# 86 thus
# 16 tibb
# 44 ticket
# 65 tie
# 14 tiger
# 61 tight
# 35 till
# 113 tim
# 2144 time
# 12 timeless
# 13 timothi
# 19 tin
# 13 tingl
# 28 tini
# 20 tip
# 69 tire
# 18 tiresom
# 112 titan
# 257 titl
# 13 toback
# 13 tobey
# 100 today
# 47 todd
# 12 toe
# 369 togeth
# 30 toilet
# 25 token
# 132 told
# 27 toler
# 200 tom
# 21 tomb
# 62 tommi
# 33 ton
# 117 tone
# 28 tongu
# 62 toni
# 124 took
# 26 tool
# 286 top
# 26 topic
# 15 torment
# 28 torn
# 17 tornado
# 14 toro
# 14 toronto
# 39 tortur
# 41 toss
# 173 total
# 201 touch
# 101 tough
# 39 tour
# 190 toward
# 17 tower
# 283 town
# 144 toy
# 26 trace
# 23 traci
# 134 track
# 39 trade
# 23 trademark
# 89 tradit
# 16 traffic
# 65 tragedi
# 48 tragic
# 25 trail
# 134 trailer
# 135 train
# 20 trait
# 19 transcend
# 26 transfer
# 55 transform
# 26 transit
# 23 translat
# 48 transport
# 14 transvestit
# 64 trap
# 35 trash
# 13 trashi
# 131 travel
# 17 travi
# 73 travolta
# 25 treasur
# 113 treat
# 38 treatment
# 38 tree
# 93 trek
# 13 trekki
# 31 tremend
# 31 trend
# 948 tri
# 45 trial
# 23 triangl
# 39 tribe
# 18 tribut
# 64 trick
# 13 trigger
# 34 trilog
# 13 trim
# 37 trio
# 104 trip
# 33 trite
# 29 triumph
# 23 troop
# 71 trooper
# 173 troubl
# 42 truck
# 297 true
# 192 truli
# 105 truman
# 16 trunk
# 66 trust
# 139 truth
# 17 tsui
# 30 tucker
# 14 tug
# 62 tune
# 15 tunnel
# 28 turkey
# 20 turmoil
# 732 turn
# 17 turturro
# 293 tv
# 16 twelv
# 91 twenti
# 74 twice
# 18 twilight
# 59 twin
# 194 twist
# 34 twister
# 1363 two
# 29 tyler
# 183 type
# 108 typic
# 13 tyson
# 56 ugli
# 13 uh
# 168 ultim
# 18 ultra
# 22 uma
# 28 un
# 35 unabl
# 12 unapp
# 17 unawar
# 18 unbear
# 56 unbeliev
# 16 uncertain
# 25 uncl
# 29 uncomfort
# 30 unconvinc
# 29 uncov
# 18 undeni
# 19 under
# 23 undercov
# 18 underdevelop
# 25 underground
# 21 undermin
# 19 underneath
# 20 underr
# 18 underst
# 192 understand
# 18 understood
# 14 underus
# 20 underworld
# 17 underwritten
# 18 undoubt
# 15 uneasi
# 23 uneven
# 71 unexpect
# 20 unfair
# 14 unfamiliar
# 41 unfold
# 17 unforgett
# 14 unforgiv
# 299 unfortun
# 63 unfunni
# 22 unhappi
# 26 uniform
# 15 unimagin
# 33 uninspir
# 42 unintent
# 54 uninterest
# 20 uninvolv
# 15 union
# 87 uniqu
# 82 unit
# 98 univers
# 45 unknown
# 62 unless
# 177 unlik
# 41 unnecessari
# 20 unorigin
# 25 unpleas
# 29 unpredict
# 13 unreal
# 22 unrealist
# 21 unrel
# 25 unsatisfi
# 18 unseen
# 17 unsettl
# 15 unsuccess
# 43 unusu
# 13 unwatch
# 13 unwit
# 60 up
# 13 upbeat
# 22 upcom
# 29 updat
# 17 uplift
# 210 upon
# 31 upper
# 26 upset
# 14 upsid
# 73 urban
# 27 urg
# 13 urgenc
# 781 us
# 16 usa
# 835 use
# 23 useless
# 278 usual
# 29 util
# 119 utter
# 49 vacat
# 17 vader
# 35 vagu
# 22 val
# 21 valentin
# 15 valjean
# 17 valley
# 85 valu
# 161 vampir
# 172 van
# 13 vanessa
# 22 vanish
# 19 vaniti
# 19 vari
# 23 variat
# 28 varieti
# 109 various
# 16 varsiti
# 25 vast
# 14 vaughn
# 600 ve
# 15 veer
# 82 vega
# 71 vehicl
# 23 velvet
# 14 vengeanc
# 17 venic
# 31 ventur
# 13 ventura
# 27 verbal
# 56 verhoeven
# 19 veronica
# 225 version
# 20 vessel
# 57 veteran
# 26 via
# 22 vice
# 27 vicious
# 135 victim
# 29 victor
# 27 victori
# 265 video
# 23 videotap
# 29 vietnam
# 226 view
# 265 viewer
# 20 vignett
# 14 vike
# 37 villag
# 182 villain
# 23 vinc
# 47 vincent
# 12 violat
# 205 violenc
# 108 violent
# 14 violin
# 14 virgil
# 24 virgin
# 20 virtu
# 107 virtual
# 56 virus
# 12 visibl
# 71 vision
# 79 visit
# 249 visual
# 27 vital
# 14 vivian
# 20 vivid
# 20 vocal
# 280 voic
# 28 voight
# 28 volcano
# 13 von
# 19 vote
# 17 vow
# 17 voyag
# 30 vs
# 12 vulgar
# 29 vulner
# 29 wacki
# 13 wade
# 18 wag
# 34 wahlberg
# 205 wait
# 21 waitress
# 51 wake
# 199 walk
# 23 walken
# 20 walker
# 91 wall
# 25 wallac
# 13 walsh
# 12 walt
# 53 walter
# 28 wan
# 57 wander
# 16 wang
# 13 wanna
# 27 wannab
# 854 want
# 397 war
# 18 ward
# 14 wardrob
# 50 warm
# 13 warmth
# 85 warn
# 34 warner
# 17 warp
# 17 warrant
# 31 warren
# 55 warrior
# 24 wash
# 48 washington
# 209 wasn
# 193 wast
# 835 watch
# 25 watchabl
# 18 watcher
# 168 water
# 37 watson
# 56 wave
# 1312 way
# 15 wayan
# 54 wayn
# 21 wcw
# 106 weak
# 12 weakest
# 20 wealth
# 41 wealthi
# 81 weapon
# 117 wear
# 23 weari
# 22 weather
# 21 weav
# 25 weaver
# 17 web
# 133 wed
# 132 week
# 44 weekend
# 38 weight
# 16 weir
# 90 weird
# 62 welcom
# 1400 well
# 17 wen
# 140 went
# 46 weren
# 33 wes
# 13 wesley
# 123 west
# 51 western
# 13 wet
# 12 whack
# 22 whale
# 91 whatev
# 27 whatsoev
# 24 wheel
# 47 whenev
# 18 wherea
# 144 whether
# 12 whimsic
# 24 whine
# 16 whip
# 18 whisper
# 219 white
# 340 whole
# 13 wholli
# 13 whore
# 302 whose
# 24 wick
# 68 wide
# 23 widow
# 16 wield
# 422 wife
# 16 wig
# 203 wild
# 72 will
# 18 willard
# 100 willi
# 289 william
# 59 williamson
# 43 wilson
# 180 win
# 68 wind
# 64 window
# 64 wing
# 62 winner
# 26 winslet
# 20 winter
# 14 wipe
# 28 wire
# 24 wisdom
# 103 wise
# 21 wisecrack
# 12 wiseguy
# 155 wish
# 179 wit
# 69 witch
# 14 witherspoon
# 171 within
# 481 without
# 75 witti
# 12 wive
# 20 wizard
# 13 wolf
# 401 woman
# 187 women
# 228 won
# 508 wonder
# 13 wondrous
# 33 wong
# 78 woo
# 119 wood
# 32 wooden
# 114 woodi
# 318 word
# 1160 work
# 76 worker
# 779 world
# 16 worm
# 22 worn
# 58 worri
# 170 wors
# 212 worst
# 222 worth
# 67 worthi
# 17 worthless
# 29 worthwhil
# 1507 would
# 141 wouldn
# 45 wound
# 21 wow
# 53 wrap
# 19 wreak
# 40 wreck
# 13 wrench
# 49 wrestl
# 23 wrestler
# 24 wright
# 264 write
# 297 writer
# 290 written
# 290 wrong
# 97 wrote
# 27 yard
# 21 yawn
# 58 yeah
# 1175 year
# 20 yearn
# 36 yell
# 14 yellow
# 203 yes
# 434 yet
# 187 york
# 503 young
# 74 younger
# 44 youth
# 13 zack
# 19 zane
# 22 zani
# 15 zemecki
# 38 zero
# 32 zeta
# 20 zombi
# 20 zone
# 18 zoom

# %%
## Naive Bayes (49% Acuuracy)
## Confusion Matrix For Testing DataSet
from sklearn.naive_bayes import GaussianNB,BernoulliNB
nb = GaussianNB().fit( train_data_features, train["Review"] )
result = nb.predict(test_data_features)
confusion_matrix(result, test['Review'])
# Out:
# array([[162, 163],
#        [125, 150]])

# %%
## Naive Bayes 
## Confusion Matrix For Training DataSet
from sklearn.naive_bayes import GaussianNB,BernoulliNB
nb = GaussianNB().fit( train_data_features, train["Review"] )
result = nb.predict(train_data_features,)
confusion_matrix(result, train['Review'])
# Out:
# array([[703, 107],
#        [ 10, 580]])

# %%
# Roc For Training DataSet
classifier = GaussianNB()
probas_ = classifier.fit(train_data_features, train['Review']).predict_proba(train_data_features)
fpr, tpr, thresholds = roc_curve(train['Review'], probas_[:, 1])
roc_auc = auc(fpr, tpr)
print "Area under the ROC curve : %f" % roc_auc

# Plot ROC curve
pl.clf()
pl.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
pl.plot([0, 1], [0, 1], 'k--')
pl.xlim([0.0, 1.0])
pl.ylim([0.0, 1.0])
pl.xlabel('False Positive Rate')
pl.ylabel('True Positive Rate')
pl.title('Receiver operating characteristic example')
pl.legend(loc="lower right")
pl.show()
# Out:
# Area under the ROC curve : 0.919130

# %%
# Roc For Testing DataSet DataSet
classifier = GaussianNB()
probas_ = classifier.fit(train_data_features, train['Review']).predict_proba(test_data_features)
fpr, tpr, thresholds = roc_curve(test['Review'], probas_[:, 1])
roc_auc = auc(fpr, tpr)
print "Area under the ROC curve : %f" % roc_auc

# Plot ROC curve
pl.clf()
pl.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
pl.plot([0, 1], [0, 1], 'k--')
pl.xlim([0.0, 1.0])
pl.ylim([0.0, 1.0])
pl.xlabel('False Positive Rate')
pl.ylabel('True Positive Rate')
pl.title('Receiver operating characteristic example')
pl.legend(loc="lower right")
pl.show()

# %%
#### In this we have used the basic NaiveBayes
#### If we choose some better classifier 
#### Decision Trees / Random Forest
#### Neural Networks
#### Support Vector Machines

#### Even Dimensionality Reduction would be very much usefull
#### Becasue here we have large number of features thus some method like
#### Principal Component Analysis Would be Helpful in this case before fitting a classifier

#### If We would use some other Vectorizer rather than CountVectorizer
#### Like BM25 which Normalizes the Term Weights with respect to the Length of the document and average length of the corpus

#### If we could make an ensemble of Term Weights and Part of Speech then I guess the classifier would work better
